# %% [markdown]
# # Extensive Feature Engineering

# %% [markdown]
# ### Prepare the flight history dataset for model making

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('Data_Train.xlsx')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
df2=pd.read_excel('Test_set.xlsx')

# %%
df2.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
df2.shape
# Out:
# (2671, 10)

# %%
df2.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info'],
#       dtype='object')

# %%
Final_dataset=df.append(df2)

# %%
Final_dataset
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
Final_dataset.tail(5)
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
Final_dataset.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %%
Final_dataset['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
Final_dataset[Final_dataset['Total_Stops'].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info   Price
# 9039  09:25 07 May  23h 40m         NaN         No info  7480.0

# %%
Final_dataset=Final_dataset.drop(9039,axis=0)

# %% [markdown]
# #### drop the missing value

# %%
Final_dataset.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 0
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           0
# Additional_Info       0
# Price              2671
# dtype: int64

# %%
Final_dataset['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder
Encoder=LabelEncoder()
Final_dataset['Airline']=Encoder.fit_transform(Final_dataset['Airline'])
# Out:
# <ipython-input-172-e15988cb6308>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_dataset['Airline']=Encoder.fit_transform(Final_dataset['Airline'])

# %%
Final_dataset['Airline']
# Out:
# 0       3
# 1       1
# 2       4
# 3       3
# 4       3
#        ..
# 2666    1
# 2667    3
# 2668    4
# 2669    1
# 2670    6
# Name: Airline, Length: 13353, dtype: int32

# %%
Final_dataset.head()
# Out:
#    Airline Date_of_Journey    Source Destination                  Route  \
# 0        3      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1        1       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2        4       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3        3      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4        3      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
Final_dataset.dtypes
# Out:
# Airline              int32
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# dtype: object

# %%
Final_dataset['Date_of_Journey'].str.split('/').str[0]
# Out:
# 0       24
# 1        1
# 2        9
# 3       12
# 4       01
#         ..
# 2666     6
# 2667    27
# 2668     6
# 2669     6
# 2670    15
# Name: Date_of_Journey, Length: 13353, dtype: object

# %%
Final_dataset['Date']=Final_dataset['Date_of_Journey'].str.split('/').str[0]
# Out:
# <ipython-input-177-92089320b7bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_dataset['Date']=Final_dataset['Date_of_Journey'].str.split('/').str[0]

# %%
Final_dataset['Date']
# Out:
# 0       24
# 1        1
# 2        9
# 3       12
# 4       01
#         ..
# 2666     6
# 2667    27
# 2668     6
# 2669     6
# 2670    15
# Name: Date, Length: 13353, dtype: object

# %%
Final_dataset['Month']=Final_dataset['Date_of_Journey'].str.split('/').str[1]
Final_dataset['Year']=Final_dataset['Date_of_Journey'].str.split('/').str[2]
# Out:
# <ipython-input-179-2307079592d0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_dataset['Month']=Final_dataset['Date_of_Journey'].str.split('/').str[1]
# <ipython-input-179-2307079592d0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_dataset['Year']=Final_dataset['Date_of_Journey'].str.split('/').str[2]

# %%
Final_dataset.head()
# Out:
#    Airline Date_of_Journey    Source Destination                  Route  \
# 0        3      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1        1       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2        4       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3        3      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4        3      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
Final_dataset['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
Encoder=LabelEncoder()
Final_dataset['Source']=Encoder.fit_transform(Final_dataset['Source'])
# Out:
# <ipython-input-182-c0de4123d7f6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_dataset['Source']=Encoder.fit_transform(Final_dataset['Source'])

# %%
Final_dataset['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
Encoder=LabelEncoder()
Final_dataset['Destination']=Encoder.fit_transform(Final_dataset['Destination'])
# Out:
# <ipython-input-184-97413026f55a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_dataset['Destination']=Encoder.fit_transform(Final_dataset['Destination'])

# %%
Final_dataset.head()
# Out:
#    Airline Date_of_Journey  Source  Destination                  Route  \
# 0        3      24/03/2019       0            5              BLR → DEL
# 1        1       1/05/2019       3            0  CCU → IXR → BBI → BLR
# 2        4       9/06/2019       2            1  DEL → LKO → BOM → COK
# 3        3      12/05/2019       3            0        CCU → NAG → BLR
# 4        3      01/03/2019       0            5        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# 3    05  2019
# ...

# %%
Final_dataset=Final_dataset.drop(columns=['Date_of_Journey'])

# %%
Final_dataset
# Out:
#       Airline  Source  Destination                  Route Dep_Time  \
# 0           3       0            5              BLR → DEL    22:20
# 1           1       3            0  CCU → IXR → BBI → BLR    05:50
# 2           4       2            1  DEL → LKO → BOM → COK    09:25
# 3           3       3            0        CCU → NAG → BLR    18:05
# 4           3       0            5        BLR → NAG → DEL    16:50
# ...       ...     ...          ...                    ...      ...
# 2666        1       3            0        CCU → DEL → BLR    20:30
# 2667        3       3            0              CCU → BLR    14:20
# 2668        4       2            1        DEL → BOM → COK    21:50
# 2669        1       2            1        DEL → BOM → COK    04:00
# 2670        6       2            1        DEL → BOM → COK    04:55
#
#       Arrival_Time Duration Total_Stops Additional_Info    Price Date Month  \
# 0     01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24    03
# ...

# %%
Final_dataset['Dep_hour']=Final_dataset['Dep_Time'].str.split(':').str[0]
Final_dataset['Dep_min']=Final_dataset['Dep_Time'].str.split(':').str[1]

# %%
Final_dataset.head()
# Out:
#    Airline  Source  Destination                  Route Dep_Time  Arrival_Time  \
# 0        3       0            5              BLR → DEL    22:20  01:10 22 Mar
# 1        1       3            0  CCU → IXR → BBI → BLR    05:50         13:15
# 2        4       2            1  DEL → LKO → BOM → COK    09:25  04:25 10 Jun
# 3        3       3            0        CCU → NAG → BLR    18:05         23:30
# 4        3       0            5        BLR → NAG → DEL    16:50         21:35
#
#   Duration Total_Stops Additional_Info    Price Date Month  Year Dep_hour  \
# 0   2h 50m    non-stop         No info   3897.0   24    03  2019       22
# 1   7h 25m     2 stops         No info   7662.0    1    05  2019       05
# 2      19h     2 stops         No info  13882.0    9    06  2019       09
# 3   5h 25m      1 stop         No info   6218.0   12    05  2019       18
# 4   4h 45m      1 stop         No info  13302.0   01    03  2019       16
#
#   Dep_min
# 0      20
# 1      50
# 2      25
# ...

# %%
Final_dataset=Final_dataset.drop(columns=['Dep_Time'])

# %%
Final_dataset
# Out:
#       Airline  Source  Destination                  Route  Arrival_Time  \
# 0           3       0            5              BLR → DEL  01:10 22 Mar
# 1           1       3            0  CCU → IXR → BBI → BLR         13:15
# 2           4       2            1  DEL → LKO → BOM → COK  04:25 10 Jun
# 3           3       3            0        CCU → NAG → BLR         23:30
# 4           3       0            5        BLR → NAG → DEL         21:35
# ...       ...     ...          ...                    ...           ...
# 2666        1       3            0        CCU → DEL → BLR  20:25 07 Jun
# 2667        3       3            0              CCU → BLR         16:55
# 2668        4       2            1        DEL → BOM → COK  04:25 07 Mar
# 2669        1       2            1        DEL → BOM → COK         19:15
# 2670        6       2            1        DEL → BOM → COK         19:15
#
#      Duration Total_Stops Additional_Info    Price Date Month  Year Dep_hour  \
# ...

# %%
Final_dataset['Arrival_hour']=Final_dataset['Arrival_Time'].str.split(':').str[0]
Final_dataset['Arrival_min']=Final_dataset['Arrival_Time'].str.split(':').str[1]

# %%
Final_dataset=Final_dataset.drop(columns=['Arrival_Time'])

# %%
Final_dataset.head()
# Out:
#    Airline  Source  Destination                  Route Duration Total_Stops  \
# 0        3       0            5              BLR → DEL   2h 50m    non-stop
# 1        1       3            0  CCU → IXR → BBI → BLR   7h 25m     2 stops
# 2        4       2            1  DEL → LKO → BOM → COK      19h     2 stops
# 3        3       3            0        CCU → NAG → BLR   5h 25m      1 stop
# 4        3       0            5        BLR → NAG → DEL   4h 45m      1 stop
#
#   Additional_Info    Price Date Month  Year Dep_hour Dep_min Arrival_hour  \
# 0         No info   3897.0   24    03  2019       22      20           01
# 1         No info   7662.0    1    05  2019       05      50           13
# 2         No info  13882.0    9    06  2019       09      25           04
# 3         No info   6218.0   12    05  2019       18      05           23
# 4         No info  13302.0   01    03  2019       16      50           21
#
#   Arrival_min
# 0   10 22 Mar
# 1          15
# 2   25 10 Jun
# ...

# %%
Final_dataset['Arrival_min']=Final_dataset['Arrival_min'].str.split(' ').str[0]

# %%
Final_dataset
# Out:
#       Airline  Source  Destination                  Route Duration  \
# 0           3       0            5              BLR → DEL   2h 50m
# 1           1       3            0  CCU → IXR → BBI → BLR   7h 25m
# 2           4       2            1  DEL → LKO → BOM → COK      19h
# 3           3       3            0        CCU → NAG → BLR   5h 25m
# 4           3       0            5        BLR → NAG → DEL   4h 45m
# ...       ...     ...          ...                    ...      ...
# 2666        1       3            0        CCU → DEL → BLR  23h 55m
# 2667        3       3            0              CCU → BLR   2h 35m
# 2668        4       2            1        DEL → BOM → COK   6h 35m
# 2669        1       2            1        DEL → BOM → COK  15h 15m
# 2670        6       2            1        DEL → BOM → COK  14h 20m
#
#      Total_Stops Additional_Info    Price Date Month  Year Dep_hour Dep_min  \
# 0       non-stop         No info   3897.0   24    03  2019       22      20
# ...

# %%
Final_dataset['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
Encoder=LabelEncoder()
Final_dataset['Total_Stops']=Encoder.fit_transform(Final_dataset['Total_Stops'])

# %%
Final_dataset.head()
# Out:
#    Airline  Source  Destination                  Route Duration  Total_Stops  \
# 0        3       0            5              BLR → DEL   2h 50m            4
# 1        1       3            0  CCU → IXR → BBI → BLR   7h 25m            1
# 2        4       2            1  DEL → LKO → BOM → COK      19h            1
# 3        3       3            0        CCU → NAG → BLR   5h 25m            0
# 4        3       0            5        BLR → NAG → DEL   4h 45m            0
#
#   Additional_Info    Price Date Month  Year Dep_hour Dep_min Arrival_hour  \
# 0         No info   3897.0   24    03  2019       22      20           01
# 1         No info   7662.0    1    05  2019       05      50           13
# 2         No info  13882.0    9    06  2019       09      25           04
# 3         No info   6218.0   12    05  2019       18      05           23
# 4         No info  13302.0   01    03  2019       16      50           21
#
#   Arrival_min
# 0          10
# 1          15
# ...

# %%
Final_dataset=Final_dataset.drop(columns=['Route'])

# %% [markdown]
# #### Total_stops and route columns provide the type of information. So delete route column.

# %%
Final_dataset.head()
# Out:
#    Airline  Source  Destination Duration  Total_Stops Additional_Info  \
# 0        3       0            5   2h 50m            4         No info
# 1        1       3            0   7h 25m            1         No info
# 2        4       2            1      19h            1         No info
# 3        3       3            0   5h 25m            0         No info
# 4        3       0            5   4h 45m            0         No info
#
#      Price Date Month  Year Dep_hour Dep_min Arrival_hour Arrival_min
# 0   3897.0   24    03  2019       22      20           01          10
# 1   7662.0    1    05  2019       05      50           13          15
# 2  13882.0    9    06  2019       09      25           04          25
# 3   6218.0   12    05  2019       18      05           23          30
# 4  13302.0   01    03  2019       16      50           21          35

# %%
Final_dataset['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
Encoder=LabelEncoder()
Final_dataset['Additional_Info']=Encoder.fit_transform(Final_dataset['Additional_Info'])

# %%
Final_dataset.head()
# Out:
#    Airline  Source  Destination Duration  Total_Stops  Additional_Info  \
# 0        3       0            5   2h 50m            4                8
# 1        1       3            0   7h 25m            1                8
# 2        4       2            1      19h            1                8
# 3        3       3            0   5h 25m            0                8
# 4        3       0            5   4h 45m            0                8
#
#      Price Date Month  Year Dep_hour Dep_min Arrival_hour Arrival_min
# 0   3897.0   24    03  2019       22      20           01          10
# 1   7662.0    1    05  2019       05      50           13          15
# 2  13882.0    9    06  2019       09      25           04          25
# 3   6218.0   12    05  2019       18      05           23          30
# 4  13302.0   01    03  2019       16      50           21          35

# %%
Final_dataset['Duration_hour']=Final_dataset['Duration'].str.split(' ').str[0]
Final_dataset['Duration_min']=Final_dataset['Duration'].str.split(' ').str[1]

# %%
Final_dataset.head()
# Out:
#    Airline  Source  Destination Duration  Total_Stops  Additional_Info  \
# 0        3       0            5   2h 50m            4                8
# 1        1       3            0   7h 25m            1                8
# 2        4       2            1      19h            1                8
# 3        3       3            0   5h 25m            0                8
# 4        3       0            5   4h 45m            0                8
#
#      Price Date Month  Year Dep_hour Dep_min Arrival_hour Arrival_min  \
# 0   3897.0   24    03  2019       22      20           01          10
# 1   7662.0    1    05  2019       05      50           13          15
# 2  13882.0    9    06  2019       09      25           04          25
# 3   6218.0   12    05  2019       18      05           23          30
# 4  13302.0   01    03  2019       16      50           21          35
#
#   Duration_hour Duration_min
# 0            2h          50m
# 1            7h          25m
# ...

# %%
Final_dataset['Duration_hour']=Final_dataset['Duration_hour'].str.replace('h',' ')

# %%
Final_dataset.head()
# Out:
#    Airline  Source  Destination Duration  Total_Stops  Additional_Info  \
# 0        3       0            5   2h 50m            4                8
# 1        1       3            0   7h 25m            1                8
# 2        4       2            1      19h            1                8
# 3        3       3            0   5h 25m            0                8
# 4        3       0            5   4h 45m            0                8
#
#      Price Date Month  Year Dep_hour Dep_min Arrival_hour Arrival_min  \
# 0   3897.0   24    03  2019       22      20           01          10
# 1   7662.0    1    05  2019       05      50           13          15
# 2  13882.0    9    06  2019       09      25           04          25
# 3   6218.0   12    05  2019       18      05           23          30
# 4  13302.0   01    03  2019       16      50           21          35
#
#   Duration_hour Duration_min
# 0            2           50m
# 1            7           25m
# ...

# %%
Final_dataset['Duration_min']=Final_dataset['Duration_min'].str.replace('m',' ')

# %%
Final_dataset['Duration_min'].isnull().sum()
# Out:
# 1286

# %%
Final_dataset['Duration_min']=Final_dataset['Duration_min'].fillna(0)

# %%
Final_dataset['Duration_min'].isnull().sum()
# Out:
# 0

# %%
Final_dataset.head()
# Out:
#    Airline  Source  Destination Duration  Total_Stops  Additional_Info  \
# 0        3       0            5   2h 50m            4                8
# 1        1       3            0   7h 25m            1                8
# 2        4       2            1      19h            1                8
# 3        3       3            0   5h 25m            0                8
# 4        3       0            5   4h 45m            0                8
#
#      Price Date Month  Year Dep_hour Dep_min Arrival_hour Arrival_min  \
# 0   3897.0   24    03  2019       22      20           01          10
# 1   7662.0    1    05  2019       05      50           13          15
# 2  13882.0    9    06  2019       09      25           04          25
# 3   6218.0   12    05  2019       18      05           23          30
# 4  13302.0   01    03  2019       16      50           21          35
#
#   Duration_hour Duration_min
# 0            2           50
# 1            7           25
# ...

# %%
Final_dataset=Final_dataset.drop(columns=['Duration'])

# %%
Final_dataset.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price Date  \
# 0        3       0            5            4                8   3897.0   24
# 1        1       3            0            1                8   7662.0    1
# 2        4       2            1            1                8  13882.0    9
# 3        3       3            0            0                8   6218.0   12
# 4        3       0            5            0                8  13302.0   01
#
#   Month  Year Dep_hour Dep_min Arrival_hour Arrival_min Duration_hour  \
# 0    03  2019       22      20           01          10            2
# 1    05  2019       05      50           13          15            7
# 2    06  2019       09      25           04          25           19
# 3    05  2019       18      05           23          30            5
# 4    03  2019       16      50           21          35            4
#
#   Duration_min
# 0          50
# 1          25
# 2            0
# 3          25
# ...

# %%
Final_dataset.dtypes
# Out:
# Airline              int32
# Source               int32
# Destination          int32
# Total_Stops          int32
# Additional_Info      int32
# Price              float64
# Date                object
# Month               object
# Year                object
# Dep_hour            object
# Dep_min             object
# Arrival_hour        object
# Arrival_min         object
# Duration_hour       object
# Duration_min        object
# dtype: object

# %%
Final_dataset['Duration_hour'].unique()
# Out:
# array(['2 ', '7 ', '19 ', '5 ', '4 ', '15 ', '21 ', '25 ', '13 ', '12 ',
#        '26 ', '22 ', '23 ', '20 ', '10 ', '6 ', '11 ', '8 ', '16 ', '3 ',
#        '27 ', '1 ', '14 ', '9 ', '18 ', '17 ', '24 ', '30 ', '28 ', '29 ',
#        '37 ', '34 ', '38 ', '35 ', '36 ', '47 ', '33 ', '32 ', '31 ',
#        '42 ', '39 ', '5m', '41 ', '40 '], dtype=object)

# %%
Final_dataset[Final_dataset['Duration_hour']=='5m']
# Out:
#       Airline  Source  Destination  Total_Stops  Additional_Info    Price  \
# 6474        1       4            3            1                8  17327.0
# 2660        1       4            3            1                8      NaN
#
#       Date  Month  Year  Dep_hour  Dep_min  Arrival_hour  Arrival_min  \
# 6474     6      3  2019        16       50            16           55
# 2660    12      3  2019        16       50            16           55
#
#      Duration_hour Duration_min
# 6474            5m            0
# 2660            5m            0

# %%
Final_dataset=Final_dataset.drop(6474,axis=0)

# %%
Final_dataset=Final_dataset.drop(2660,axis=0)

# %%
Final_dataset['Date']=Final_dataset['Date'].astype(int)
Final_dataset['Month']=Final_dataset['Month'].astype(int)
Final_dataset['Year']=Final_dataset['Year'].astype(int)
Final_dataset['Dep_hour']=Final_dataset['Dep_hour'].astype(int)
Final_dataset['Dep_min']=Final_dataset['Dep_min'].astype(int)
Final_dataset['Arrival_hour']=Final_dataset['Arrival_hour'].astype(int)
Final_dataset['Arrival_min']=Final_dataset['Arrival_min'].astype(int)
Final_dataset['Duration_hour']=Final_dataset['Duration_hour'].astype(int)
Final_dataset['Duration_min']=Final_dataset['Duration_min'].astype(int)

# %%
Final_dataset.dtypes
# Out:
# Airline              int32
# Source               int32
# Destination          int32
# Total_Stops          int32
# Additional_Info      int32
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Dep_hour             int32
# Dep_min              int32
# Arrival_hour         int32
# Arrival_min          int32
# Duration_hour        int32
# Duration_min         int32
# dtype: object

# %%
Final_dataset.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Total_Stops           0
# Additional_Info       0
# Price              2670
# Date                  0
# Month                 0
# Year                  0
# Dep_hour              0
# Dep_min               0
# Arrival_hour          0
# Arrival_min           0
# Duration_hour         0
# Duration_min          0
# dtype: int64

# %%
Test_data=Final_dataset[Final_dataset['Price'].isnull()]

# %%
Test_data
# Out:
#       Airline  Source  Destination  Total_Stops  Additional_Info  Price  Date  \
# 0           4       2            1            0                8    NaN     6
# 1           3       3            0            0                8    NaN    12
# 2           4       2            1            0                5    NaN    21
# 3           6       2            1            0                8    NaN    21
# 4           0       0            2            4                8    NaN    24
# ...       ...     ...          ...          ...              ...    ...   ...
# 2666        1       3            0            0                8    NaN     6
# 2667        3       3            0            4                8    NaN    27
# 2668        4       2            1            0                8    NaN     6
# 2669        1       2            1            0                8    NaN     6
# 2670        6       2            1            0                8    NaN    15
#
# ...

# %%
Train_data=Final_dataset[~Final_dataset['Price'].isnull()]

# %%
Train_data
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info    Price  \
# 0            3       0            5            4                8   3897.0
# 1            1       3            0            1                8   7662.0
# 2            4       2            1            1                8  13882.0
# 3            3       3            0            0                8   6218.0
# 4            3       0            5            0                8  13302.0
# ...        ...     ...          ...          ...              ...      ...
# 10678        0       3            0            4                8   4107.0
# 10679        1       3            0            4                8   4145.0
# 10680        4       0            2            4                8   7229.0
# 10681       10       0            5            4                8  12648.0
# 10682        1       2            1            1                8  11753.0
#
# ...

# %%
X=Train_data.drop(columns=['Price'])

# %%
X
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Date  \
# 0            3       0            5            4                8    24
# 1            1       3            0            1                8     1
# 2            4       2            1            1                8     9
# 3            3       3            0            0                8    12
# 4            3       0            5            0                8     1
# ...        ...     ...          ...          ...              ...   ...
# 10678        0       3            0            4                8     9
# 10679        1       3            0            4                8    27
# 10680        4       0            2            4                8    27
# 10681       10       0            5            4                8     1
# 10682        1       2            1            1                8     9
#
#        Month  Year  Dep_hour  Dep_min  Arrival_hour  Arrival_min  \
# ...

# %%
Target=Train_data['Price']

# %%
Target
# Out:
# 0         3897.0
# 1         7662.0
# 2        13882.0
# 3         6218.0
# 4        13302.0
#           ...
# 10678     4107.0
# 10679     4145.0
# 10680     7229.0
# 10681    12648.0
# 10682    11753.0
# Name: Price, Length: 10680, dtype: float64
